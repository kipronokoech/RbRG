# %%
import os
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
PATH=r"/home/kiprono/Desktop/misc-project/dataset"

# %%
# Import the os module, for the os.walk function
import os
import cv2
import matplotlib.pyplot as plt
# Set the directory you want to start from
rootDir = "/home/kiprono/Desktop/misc-project/dataset/"
for dirName, subdirList, fileList in os.walk(rootDir):
    #print('Found directory: %s' % subdirList)
    for fname in fileList:
        #print('\t%s' % fname)
        if  fname.endswith(".jpg"):
            print(fname)
            im=cv2.imread(fname,0)
            plt.imshow(im,cmap="gray")
            plt.show()
            print(type(im))
# Out:
# 1-49-0049.jpg
# <class 'numpy.ndarray'>
# 1-10-0010.jpg
# <class 'numpy.ndarray'>
# 1-62-0062.jpg
# ----------------------------------------------------
# TypeError          Traceback (most recent call last)
# <ipython-input-8-b6a5780340a2> in <module>()
#      12             print(fname)
#      13             im=cv2.imread(fname,0)
# ---> 14             plt.imshow(im,cmap="gray")
#      15             plt.show()
#      16             print(type(im))
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1810                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1811                         RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813
#    1814         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in set_data(self, A)
#     640         if (self._A.dtype != np.uint8 and
#     641                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 642             raise TypeError("Image data cannot be converted to float")
#     643
#     644         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
# Import the os module, for the os.walk function
import os
 
# Set the directory you want to start from
rootDir = r"/home/kiprono/Desktop/misc-project/dataset/"
dirr=[]
for item in os.listdir(rootDir):
    m=os.path.abspath(item) 
    dirr.append(m)

# %%
dirr
# Out:
# ['/var/autofs/misc/home/kiprono/Desktop/research-project-Kiprono/Python/RbRG/Python/1-25-0025',
#  '/var/autofs/misc/home/kiprono/Desktop/research-project-Kiprono/Python/RbRG/Python/1-10-0010']

# %%
for entry in dirr:
    entry=os.path.realpath(entry)  
    print(entry)
# Out:
# /var/autofs/misc/home/kiprono/Desktop/research-project-Kiprono/Python/RbRG/Python/1-25-0025
# /var/autofs/misc/home/kiprono/Desktop/research-project-Kiprono/Python/RbRG/Python/1-10-0010

# %%
PATH=r"/home/kiprono/Desktop/misc-project/dataset"

# %%
def show_cwd_contents(PATH ): 
    # A function that calls 2 functions to separately  
    # listing out directories and files. 
    # It takes a default argument as cwd(.). We can  
    # pass other paths too. 
    import os 
  
    f_list = [] 
    d_list = list() 
  
    try: 
        for f in os.listdir(path): 
            if os.path.isfile(os.path.join(path, f)): 
                f_list.append(f) 
            else: 
                if os.path.isdir(os.path.join(path, f)): 
                    d_list.append(f) 
    except: 
        print ("\nError, once check the path")
        return
  
    show_files(f_list, path) 
  
    show_directories(d_list, path)

# %%
# This Python code is for Python version : 2.7.12 

def show_directories(dir_list, path): 
	""" A function that lists the directories """
	import os 
	s = "%s%d%s"%("\n", len(dir_list), " directories of " + os.path.abspath(path)) 
	l = len(s) 
	print (s)
	print ("="*l) 
	for index, dir in enumerate(dir_list): 
		print (str(index+1) + ") ", dir)


def show_files(file_list, path): 
	""" A function that lists the files """

	import os 
	s = "%s%d%s"%("\n", len(file_list), " files of " + os.path.abspath(path)) 
	l = len(s) 
	print (s) 
	print ("="*l) 
	for index, file in enumerate(file_list): 
		print (str(index+1) + ") ", file)


def show_cwd_contents( path="." ): 
	# A function that calls 2 functions to separately 
	# listing out directories and files. 
	# It takes a default argument as cwd(.). We can 
	# pass other paths too. 
	import os 

	f_list = [] 
	d_list = list() 

	try: 
		for f in os.listdir(path): 
			if os.path.isfile(os.path.join(path, f)): 
				f_list.append(f) 
			else: 
				if os.path.isdir(os.path.join(path, f)): 
					d_list.append(f) 
	except: 
		print ("\nError, once check the path")
		return

	show_files(f_list, path) 

	show_directories(d_list, path) 


if __name__ == "__main__": 

	# If this module is imported in other module then 
	# we need to separately call show_cwd_contents() Or 
	# show_cwd_contents(path). 
	#show_cwd_contents() 
	show_cwd_contents(PATH)
# Out:
# 0 files of /home/kiprono/Desktop/misc-project/dataset
# ======================================================
#
# 2 directories of /home/kiprono/Desktop/misc-project/dataset
# ============================================================
# 1)  1-25-0025
# 2)  1-10-0010

# %%
import os
PATH = "/home/kiprono/Desktop/misc-project/dataset"

for subdir in os.listdir(PATH):
        print(subdir)
    
#     if filename.endswith(".npy"):
#         f = open(filename)
#         lines = f.read()
#         print (lines[10])
#         continue
#     else:
#     continue
# Out:
# ('/home/kiprono/Desktop/misc-project/dataset', ['1-25-0025', '1-10-0010'], [])
# ('/home/kiprono/Desktop/misc-project/dataset/1-25-0025', [], ['1-25-0025.npy', '1-25-0025.jpg', '1-25-0025_predictions.npy'])
# ('/home/kiprono/Desktop/misc-project/dataset/1-10-0010', [], ['1-10-0010.npy', '1-10-0010_predictions.npy', '1-10-0010.jpg'])

# %%
import os

# List all files in a directory using os.listdir
basepath = '/home/kiprono/Desktop/Essay-Koech/dataset'
for entry in os.listdir(basepath):
    if os.path.isdir(os.path.join(basepath, entry))==True:
        subdir=entry
        for files in subdir:
            im2=cv.imread(files)
            plt(im2)
# Out:
# ----------------------------------------------------
# TypeError          Traceback (most recent call last)
# <ipython-input-45-ecbebd5beaab> in <module>()
#       8         for files in subdir:
#       9             im2=cv.imread(files)
# ---> 10             plt(im2)
#
# TypeError: 'module' object is not callable

# %%
rootdir = '/home/kiprono/Desktop/Essay-Koech/dataset'
for subdir in os.walk(rootdir):
    for file in subdir:
        im2=cv.imread(str(file))
        print(str(file))
        pts=np.load(str(file), allow_pickle=True)
        #pts = np.array(pickle.load(open("1-49-0049.npy","rb")))
        img = cv.polylines(im2,np.int32(pts),True,(255,0,0),8)
        print("********************")
        #img_cvt=cv.cvtColor(img,cv.COLOR_BGR2RGB)
        cv.imwrite("file.jpg", img)
# Out:
# /home/kiprono/Desktop/Essay-Koech/dataset
# ----------------------------------------------------
# IsADirectoryError  Traceback (most recent call last)
# <ipython-input-32-347d0db77614> in <module>()
#       4         im2=cv.imread(str(file))
#       5         print(str(file))
# ----> 6         pts=np.load(str(file), allow_pickle=True)
#       7         #pts = np.array(pickle.load(open("1-49-0049.npy","rb")))
#       8         img = cv.polylines(im2,np.int32(pts),True,(255,0,0),8)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# IsADirectoryError: [Errno 21] Is a directory: '/home/kiprono/Desktop/Essay-Koech/dataset'

# %%
# Import the os module, for the os.walk function
import os
 
# Set the directory you want to start from
rootDir = "/home/kiprono/Desktop/misc-project/dataset"
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        if fname.endswith(".npy"):
            print(fname)
        elif fname.endswith("predictions.npy"):
            pt = np.array(pickle.load(open(fname,"rb")))
            pt
            print(fname)
        #print('\t%s' % fname)
